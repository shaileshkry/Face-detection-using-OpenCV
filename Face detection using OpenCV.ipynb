# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv

# %%
img=cv.imread('shailesh.jpg')

# %%
plt.imshow(img)

# %%
img=cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img)

# %%
classifier=cv.CascadeClassifier('haarcascade_frontalface_default.xml')

# %%
#img=cv.cvtColor(img,cv.COLOR_BGR2GRAY)

# %%
plt.imshow(img)

# %%
faces=classifier.detectMultiScale(img,1.05,5)

# %%
for (x,y,w,h) in faces:
    cv.rectangle(img,(x,y),(x+w,y+h),(255,0,0),10)
plt.imshow(img)

# %% [markdown]
# ### Croping the face

# %%
print(x,y,w,h)
# Out:
# 274 152 527 527

# %%
plt.imshow(img[y:y+h,x:x+w])

# %%
#Drawing Circle
for (x,y,w,h) in faces:
    cv.circle(img,(int(x+w/2),int(y+h/2)),int(w/2),(255,0,0),10)
plt.imshow(img)
